# %%
from utils.barrel_over_time_utils import *

player_name = "Shohei Ohtani"
batter = 660271
count = "other"
attack_direction_slope_multiplier = 1.0
attack_angle_slope_multiplier = 1.0
pitch_speed = 95
init_plate_x = -8.5
init_int_y = 12
final_x_intercept = 8.5

bat_path_over_time_full(
    player_name,
    batter,
    count,
    attack_direction_slope_multiplier,
    attack_angle_slope_multiplier,
    pitch_speed,
    init_plate_x,
    init_int_y,
    final_x_intercept,
)
